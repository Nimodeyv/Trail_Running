# %%
import folium
import folium.plugins as plugins
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import ipywidgets as widgets

# %%
class trail:
    def __init__(self,nom_id,d,s,hd,csv):
        self.nom_id = nom_id
        self.date = d
        self.suivi = s
        self.heure_depart =hd
        self.csv_file =csv
        
    def pred_temps(self, vit_plat,vit_Dplus,ralentissement,durée_stop,à_partir_de):
        print('Opti.: Vit_plat_km/h:',vit_plat,' | Vit_den+_m/h:', vit_Dplus,' | Ralent.:',ralentissement)
        df = self.df_ppassage
        df['Pred_Cum_T_Rom']=0 
        df['Pred_T_Rom']=0
        df['Pred_T_Rom']=round(df['Delta_Dist_km']/vit_plat+df['Delta_D+_m']/vit_Dplus+df['Cumul_Dist_km']*ralentissement,2)
        # df['Heure_predite']= 
        for i in range(1,len(df)):             
            df.loc[i,'Pred_Cum_T_Rom']=df.loc[i-1,'Pred_Cum_T_Rom']+df.loc[i,'Pred_T_Rom']
        for i in range(1,len(df)): 
            if df.loc[i,'Pred_Cum_T_Rom']>à_partir_de:
                df.loc[i,'Pred_Cum_T_Rom']=df.loc[i,'Pred_Cum_T_Rom']+durée_stop
            df.loc[i,'Heure_predite']=(pd.to_datetime(f'{self.date} {self.heure_depart}')+pd.Timedelta(hours=(df.loc[i,'Pred_Cum_T_Rom']//1), minutes= (df.loc[i,'Pred_Cum_T_Rom']%1*60))).strftime("%a. %H:%M")         
            df.loc[i,'DELTA']=round(df.loc[i,'Pred_Cum_T_Rom']-df.loc[i,'H_reel_h_init'],2)
        return df
    
    def plot_parcours(self,vit_plat,vit_Dplus,ralentissement):
        pts = [ (x,y) for x,y in zip(self.df_parcours['lat'],self.df_parcours['lon'])]
        map = folium.Map(location=[self.df_parcours['lat'].mean(), self.df_parcours['lon'].mean()], zoom_start=12)
        folium.PolyLine(pts).add_to(map)
        geo_df_list = [ (x,y) for x,y in zip(self.df_ppassage['lat'],self.df_ppassage['lon'])]
        for i, coordinates in enumerate(geo_df_list):
            txt = ''
            ic ='cloud'   
            couleur='blue'
            popContent = f''' {str(self.df_ppassage.loc[i,'Point_passage'])}
                            <style>
                            table, th, td {{
                              border: 1px solid black;
                              border-collapse: collapse;
                              text-align: center; 
                                }}
                            </style> 
                            <table style="width:100%">
                              <tr>
                                <th>Distance:</th>
                                <th>Altitude:</th>
                                <th>D+:</th>
                              </tr>
                              <tr>
                               <td>{str(self.df_ppassage.loc[i,'Cumul_Dist_km'])} km</td>
                               <td>{str(self.df_ppassage.loc[i,'Altitude_m'])} m</td>
                               <td>{str(self.df_ppassage.loc[i,'Cumul_D+_m'])} m</td>
                               </tr>
                               <tr>
                                <th>Heure Passage:</th>
                                <th>Heure Predite:</th>
                               </tr>
                               <tr>
                               <td>{str(self.df_ppassage.loc[i,'Heure_Passage'])}</td>
                               <td>{str(self.df_ppassage.loc[i,'Heure_predite'])}</td>
                               </tr>
                               </table> '''
            iframe = folium.IFrame(popContent)
            popup1 = folium.Popup(iframe,
                                  min_width=350,
                                  max_width=400)   
            folium.Marker(location=coordinates,
                           popup = popup1,            
                           icon=plugins.BeautifyIcon(
                           icon="arrow-down", icon_shape="marker",
                           number=i,
                           )).add_to(map)
        #     folium.Marker(location=coordinates,
        #                    popup = popup1,            
        #                    icon=folium.Icon(color=couleur,icon=ic,prefix='fa')).add_to(map)
        # map.save(f'{self.nom_id}_{vit_plat}_{vit_Dplus}_{ralentissement}.html')
        display(map)

# %%
Lst_trails = pd.read_csv('ListeDesTrails.csv',sep=',')

# %%
PIK = "trails.dat"
Trails_objects = []
with open(PIK, "rb") as f:
    while True:
        try:
            Trails_objects.append(pickle.load(f))
        except EOFError:
            break

# %%
for i,T in enumerate(Trails_objects):
    print(i,T.nom_id,T.date,T.suivi,T.heure_depart,T.csv_file)
# Out:
# 0 20195REFUGES 2019-07-28 livetrail 07:30:00 2019-07-28_5ref_31.7km.csv
# 1 2019MCC 2019-08-26 livetrail 10:00:00 2019-08-26_MCC_39.1km.csv
# 2 2020GTC 2020-09-13 livetrail 06:00:00 2020-09-13_GTC_56.5km.csv
# 3 20218REFUGES 2021-07-25 livetrail 05:00:00 2021-07-25_Tour des 8 refuges Evadict_65.1km.csv
# 4 2021DOOBLE 2021-07-31 livetrail 08:00:00 2021-07-31_LA DOOBLE - 16 KM_17.9km.csv
# 5 2021TRAVNORD 2021-08-21 livetrail 05:15:00 2021-08-21_Traversée Nord_83.4km.csv
# 6 2022UTHG 2022-06-17 livetrail  23:45:00 2022-06-17_Ultra-Trail® du haut-Giffre_97.4km.csv
# 7 2022MBM 2022-06-25 livetrail 08:00:00 2022-06-24_23km du Mont-Blanc_24.4km.csv
# 8 2022UTB 2022-07-16 livetrack 04:00:00 2022-07-16_Ultra Tour du Beaufortain 2022 Solos_114.0km.csv
# 9 All 1979-12-05 NA NA NA

# %% [markdown]
# # Visualisation des résultats et predictions

# %%
durée_arret = 1.25
à_partir_de = 13
def pred(i,vit_plat,vit_Dplus,ralentissement):
    df_p = Trails_objects[i].pred_temps(vit_plat,vit_Dplus,ralentissement,durée_arret,à_partir_de)
    df_p['H_reel_h']=round(df_p['H_reel_h'],2)
    display(df_p[['Point_passage','Cumul_Dist_km','Cumul_D+_m','Pred_Cum_T_Rom','Heure_Passage','Heure_predite','DELTA']])
    return df_p

# %%
def parcours_plot(i,vit_plat,vit_Dplus,ralentissement):
    Trails_objects[i].plot_parcours(vit_plat,vit_Dplus,ralentissement)

# %%
Trail_selection = widgets.Dropdown(
    options=[(Trails_objects[i].nom_id,i) for i in range(len(Trails_objects))],
    value=0,
    description='Trail:',
)
vitesse_plat = widgets.FloatSlider(
    value=Trails_objects[-1].vit_plat,
    min=4.0,
    max=15.0,
    step=0.1,
    description='Vitesse plat:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)
vitesse_Dplus = widgets.FloatSlider(
    value=Trails_objects[-1].vit_Dplus,
    min=600,
    max=1900,
    step=25,
    description='Vitesse D+:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)
Ralentissement = widgets.FloatSlider(
    value=Trails_objects[-1].ralentissement,
    min=0,
    max=0.01,
    step=0.001,
    description='Ralentissement:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.5f',
)
ui = widgets.HBox([Trail_selection, vitesse_plat,vitesse_Dplus,Ralentissement])
res= widgets.interactive_output(pred,{'i':Trail_selection,'vit_plat':vitesse_plat,'vit_Dplus':vitesse_Dplus,'ralentissement':Ralentissement})
graph = widgets.interactive_output(parcours_plot,{'i':Trail_selection,'vit_plat':vitesse_plat,'vit_Dplus':vitesse_Dplus,'ralentissement':Ralentissement})
out = widgets.HBox([graph,res])

# display(ui,out)
display(graph,ui,res)
# Out:
# Output()
# HBox(children=(Dropdown(description='Trail:', options=(('20195REFUGES', 0), ('2019MCC', 1), ('2020GTC', 2), ('…
# Output()

# %%
Lst_trails
# Out:
#           Trail        Date      Suivi Heure_depart  \
# 0  20195REFUGES  2019-07-28  livetrail     07:30:00
# 1       2019MCC  2019-08-26  livetrail     10:00:00
# 2       2020GTC  2020-09-13  livetrail     06:00:00
# 3  20218REFUGES  2021-07-25  livetrail     05:00:00
# 4    2021DOOBLE  2021-07-31  livetrail     08:00:00
# 5  2021TRAVNORD  2021-08-21  livetrail     05:15:00
# 6      2022UTHG  2022-06-17  livetrail     23:45:00
# 7       2022MBM  2022-06-25  livetrail     08:00:00
# 8       2022UTB  2022-07-16  livetrack     04:00:00
#
#                                             Lien_URL  \
# 0   https://livetrail.net/histo/fiz_2019/coureur.php
# 1  https://livetrail.net/histo/utmb_2019/coureur.php
# 2  https://livetrail.net/histo/serreche_2020/cour...
# 3              https://fiz.livetrail.net/coureur.php
# 4  https://megevenaturetrail.livetrail.run/coureu...
# 5   https://echappeebelle.livetrail.run/parcours....
# 6  https://ultratrailduhautgiffre.livetrail.run/c...
# 7              https://mbm.livetrail.run/coureur.php
# 8  https://www.livetrack.me/fr/evenement/ultratou...
#
#                                 Fichier_parcours_gpx  Vit_plat_km/h  \
# 0                                                NaN           10.0
# 1                             tracedetrail_94254.gpx            6.9
# 2                                                NaN            7.0
# 3                            tracedetrail_156428.gpx            8.4
# 4                                                NaN           13.5
# 5                            tracedetrail_135447.gpx            5.2
# 6                            tracedetrail_166975.gpx            6.0
# 7                                      23km-2022.gpx           11.1
# 8  ultra_tour_du_beaufortain_2022-13673263-165493...            NaN
#
#    Vit_den+_m/h                                           Csv_file     Date_dt
# 0        1229.8                         2019-07-28_5ref_31.7km.csv  2019-07-28
# 1        2933.5                          2019-08-26_MCC_39.1km.csv  2019-08-26
# 2        1314.0                          2020-09-13_GTC_56.5km.csv  2020-09-13
# 3        1217.6   2021-07-25_Tour des 8 refuges Evadict_65.1km.csv  2021-07-25
# 4        1643.0            2021-07-31_LA DOOBLE - 16 KM_17.9km.csv  2021-07-31
# 5        2137.3               2021-08-21_Traversée Nord_83.4km.csv  2021-08-21
# 6        1283.3  2022-06-17_Ultra-Trail® du haut-Giffre_97.4km.csv  2022-06-17
# 7         767.8           2022-06-24_23km du Mont-Blanc_24.4km.csv  2022-06-25
# 8           NaN  2022-07-16_Ultra Tour du Beaufortain 2022 Solo...  2022-07-16

# %%
df2 = pred(8,6,1283,0)
df2['UTHG 6 1283 0']=df2['Heure_predite']
df2 = pred(8,5.2,2137,0)
df2['TRAV 5.2 2137 0']=df2['Heure_predite']
df2 = pred(8,5.8,1275,0)
df2['UTHG+TRAV 5.8 1275 0']=df2['Heure_predite']
df2 = pred(8,6.9,1284,0)
df2['ALL 6.9 1284 0']=df2['Heure_predite']
# df2 = pred(8,8.8,949,0.00559)
# df2['ALL 8.8 949 0.00559']=df2['Heure_predite']
# Out:
# Opti.: Vit_plat_km/h: 6  | Vit_den+_m/h: 1283  | Ralent.: 0
#                        Point_passage  Cumul_Dist_km  Cumul_D+_m  \
# 0                             Départ            0.0           0
# 1              Gîte de Molliessoulaz            4.0         422
# 2                        Les Chappes            7.0         898
# 3                       Frêtte basse            9.0        1453
# 4                       Col des Lacs           13.0        1771
# 5                 Chalet du Soufflet           16.0        1777
# 6               Ardoisière de Cevins           18.0        1991
# 7                  Col des Combettes           21.0        2254
# 8             Col des Bonnets rouges           25.0        2452
# 9                   Lac de St Guerin           30.0        2465
# 10                      Lac des Fées           33.0        2794
# 11                       Col du Coin           37.0        3300
# 12                       Lac d'amour           39.0        3307
# 13                        Col à Tutu           40.0        3599
# 14                 Refuge de Presset           42.0        3686
# 15                 Col du grand Fond           43.0        3839
# 16                Cormet de Roselend           49.0        3851
# 17             Tunnel du Roc du Vent           54.0        4179
# 18                   Col de la Sauce           57.0        4408
# 19    Refuge de la Croix du Bonhomme           60.0        4648
# 20                   Col du Bonhomme           62.0        4704
# 21               Hameau de la Gittaz           66.0        4730
# 22             Faux Col de la Gittaz           70.0        5357
# 23                          Lac noir           73.0        5470
# 24                        La Girotte           77.0        5552
# 25               Lac du Bout de Crêt           81.0        5944
# 26                      Pas d'Outray           83.0        6104
# 27                        La Journée           86.0        6104
# 28                         Hauteluce           92.0        6219
# 29                        Les Jorets           95.0        6772
# 30  Les Saisies - Office du Tourisme          100.0        6848
# 31                    Le Lata du Vaz          104.0        7165
# 32                  Plan des Maisons          109.0        7194
# 33                            Queige          113.0        7197
# 34                           Arrivée          114.0        7200
#
#     Pred_Cum_T_Rom Heure_Passage Heure_predite  DELTA
# 0             0.00      04:00:00           NaN    NaN
# 1             1.00           NaN    Sat. 05:00   1.00
# 2             1.87           NaN    Sat. 05:52   1.87
# 3             2.64           NaN    Sat. 06:38   2.64
# 4             3.55           NaN    Sat. 07:33   3.55
# 5             4.05           NaN    Sat. 08:03   4.05
# 6             4.55           NaN    Sat. 08:33   4.55
# 7             5.25           NaN    Sat. 09:15   5.25
# 8             6.07           NaN    Sat. 10:04   6.07
# 9             6.91           NaN    Sat. 10:54   6.91
# 10            7.67           NaN    Sat. 11:40   7.67
# 11            8.73           NaN    Sat. 12:43   8.73
# 12            9.07           NaN    Sat. 13:04   9.07
# 13            9.46           NaN    Sat. 13:27   9.46
# 14            9.86           NaN    Sat. 13:51   9.86
# 15           10.15           NaN    Sat. 14:09  10.15
# 16           11.16           NaN    Sat. 15:09  11.16
# 17           12.25           NaN    Sat. 16:15  12.25
# 18           12.93           NaN    Sat. 16:55  12.93
# 19           14.87           NaN    Sat. 18:52  14.87
# 20           15.25           NaN    Sat. 19:15  15.25
# 21           15.94           NaN    Sat. 19:56  15.94
# 22           17.10           NaN    Sat. 21:06  17.10
# 23           17.69           NaN    Sat. 21:41  17.69
# 24           18.42           NaN    Sat. 22:25  18.42
# 25           19.39           NaN    Sat. 23:23  19.39
# 26           19.85           NaN    Sat. 23:51  19.85
# 27           20.35           NaN    Sun. 00:21  20.35
# 28           21.44           NaN    Sun. 01:26  21.44
# 29           22.37           NaN    Sun. 02:22  22.37
# 30           23.26           NaN    Sun. 03:15  23.26
# 31           24.17           NaN    Sun. 04:10  24.17
# 32           25.03           NaN    Sun. 05:01  25.03
# 33           25.70           NaN    Sun. 05:42  25.70
# 34           25.87           NaN    Sun. 05:52  25.87
# Opti.: Vit_plat_km/h: 5.2  | Vit_den+_m/h: 2137  | Ralent.: 0
#                        Point_passage  Cumul_Dist_km  Cumul_D+_m  \
# 0                             Départ            0.0           0
# 1              Gîte de Molliessoulaz            4.0         422
# 2                        Les Chappes            7.0         898
# 3                       Frêtte basse            9.0        1453
# 4                       Col des Lacs           13.0        1771
# 5                 Chalet du Soufflet           16.0        1777
# 6               Ardoisière de Cevins           18.0        1991
# 7                  Col des Combettes           21.0        2254
# 8             Col des Bonnets rouges           25.0        2452
# 9                   Lac de St Guerin           30.0        2465
# 10                      Lac des Fées           33.0        2794
# 11                       Col du Coin           37.0        3300
# 12                       Lac d'amour           39.0        3307
# 13                        Col à Tutu           40.0        3599
# 14                 Refuge de Presset           42.0        3686
# 15                 Col du grand Fond           43.0        3839
# 16                Cormet de Roselend           49.0        3851
# 17             Tunnel du Roc du Vent           54.0        4179
# 18                   Col de la Sauce           57.0        4408
# 19    Refuge de la Croix du Bonhomme           60.0        4648
# 20                   Col du Bonhomme           62.0        4704
# 21               Hameau de la Gittaz           66.0        4730
# 22             Faux Col de la Gittaz           70.0        5357
# 23                          Lac noir           73.0        5470
# 24                        La Girotte           77.0        5552
# 25               Lac du Bout de Crêt           81.0        5944
# 26                      Pas d'Outray           83.0        6104
# 27                        La Journée           86.0        6104
# 28                         Hauteluce           92.0        6219
# 29                        Les Jorets           95.0        6772
# 30  Les Saisies - Office du Tourisme          100.0        6848
# 31                    Le Lata du Vaz          104.0        7165
# 32                  Plan des Maisons          109.0        7194
# 33                            Queige          113.0        7197
# 34                           Arrivée          114.0        7200
#
#     Pred_Cum_T_Rom Heure_Passage Heure_predite  DELTA
# 0             0.00      04:00:00           NaN    NaN
# 1             0.97           NaN    Sat. 04:58   0.97
# 2             1.77           NaN    Sat. 05:46   1.77
# 3             2.41           NaN    Sat. 06:24   2.41
# 4             3.33           NaN    Sat. 07:19   3.33
# 5             3.91           NaN    Sat. 07:54   3.91
# 6             4.39           NaN    Sat. 08:23   4.39
# 7             5.09           NaN    Sat. 09:05   5.09
# 8             5.95           NaN    Sat. 09:57   5.95
# 9             6.92           NaN    Sat. 10:55   6.92
# 10            7.65           NaN    Sat. 11:39   7.65
# 11            8.66           NaN    Sat. 12:39   8.66
# 33                            Queige          113.0        7197
# 34                           Arrivée          114.0        7200
#
#     Pred_Cum_T_Rom Heure_Passage Heure_predite  DELTA
# 0             0.00      04:00:00           NaN    NaN
# 1             0.91           NaN    Sat. 04:54   0.91
# 2             1.72           NaN    Sat. 05:43   1.72
# 3             2.44           NaN    Sat. 06:26   2.44
# 4             3.27           NaN    Sat. 07:16   3.27
# 5             3.71           NaN    Sat. 07:42   3.71
# 6             4.17           NaN    Sat. 08:10   4.17
# 7             4.81           NaN    Sat. 08:48   4.81
# 8             5.54           NaN    Sat. 09:32   5.54
# 9             6.27           NaN    Sat. 10:16   6.27
# 10            6.96           NaN    Sat. 10:57   6.96
# 11            7.93           NaN    Sat. 11:55   7.93
# 12            8.23           NaN    Sat. 12:13   8.23
# 13            8.60           NaN    Sat. 12:36   8.60
# 14            8.96           NaN    Sat. 12:57   8.96
# 15            9.22           NaN    Sat. 13:13   9.22
# 16           10.10           NaN    Sat. 14:06  10.10
# 17           11.08           NaN    Sat. 15:04  11.08
# 18           11.69           NaN    Sat. 15:41  11.69
# 19           12.31           NaN    Sat. 16:18  12.31
# 20           12.64           NaN    Sat. 16:38  12.64
# 21           14.49           NaN    Sat. 18:29  14.49
# 22           15.56           NaN    Sat. 19:33  15.56
# 23           16.08           NaN    Sat. 20:04  16.08
# 24           16.72           NaN    Sat. 20:43  16.72
# 25           17.61           NaN    Sat. 21:36  17.61
# 26           18.02           NaN    Sat. 22:01  18.02
# 27           18.45           NaN    Sat. 22:27  18.45
# 28           19.41           NaN    Sat. 23:24  19.41
# 29           20.28           NaN    Sun. 00:16  20.28
# 30           21.06           NaN    Sun. 01:03  21.06
# 31           21.89           NaN    Sun. 01:53  21.89
# 32           22.64           NaN    Sun. 02:38  22.64
# 33           23.22           NaN    Sun. 03:13  23.22
# 34           23.37           NaN    Sun. 03:22  23.37

# %%
Trails_objects[8].df_ppassage[['Point_passage','Cumul_Dist_km','Cumul_D+_m','ALL 6.9 1284 0','UTHG+TRAV 5.8 1275 0','TRAV 5.2 2137 0','UTHG 6 1283 0']].to_html('Temps_roms_UTB.html')

# %%
Trails_objects[8].df_ppassage[['Point_passage','Cumul_Dist_km','Cumul_D+_m','ALL 6.9 1284 0','UTHG+TRAV 5.8 1275 0','TRAV 5.2 2137 0','UTHG 6 1283 0']]
# Out:
#                        Point_passage  Cumul_Dist_km  Cumul_D+_m  \
# 0                             Départ            0.0           0
# 1              Gîte de Molliessoulaz            4.0         422
# 2                        Les Chappes            7.0         898
# 3                       Frêtte basse            9.0        1453
# 4                       Col des Lacs           13.0        1771
# 5                 Chalet du Soufflet           16.0        1777
# 6               Ardoisière de Cevins           18.0        1991
# 7                  Col des Combettes           21.0        2254
# 8             Col des Bonnets rouges           25.0        2452
# 9                   Lac de St Guerin           30.0        2465
# 10                      Lac des Fées           33.0        2794
# 11                       Col du Coin           37.0        3300
# 12                       Lac d'amour           39.0        3307
# 13                        Col à Tutu           40.0        3599
# 14                 Refuge de Presset           42.0        3686
# 27     Sat. 22:27           Sun. 00:51      Sun. 00:39    Sun. 00:21
# 28     Sat. 23:24           Sun. 01:58      Sun. 01:51    Sun. 01:26
# 29     Sun. 00:16           Sun. 02:55      Sun. 02:42    Sun. 02:22
# 30     Sun. 01:03           Sun. 03:51      Sun. 03:42    Sun. 03:15
# 31     Sun. 01:53           Sun. 04:47      Sun. 04:37    Sun. 04:10
# 32     Sun. 02:38           Sun. 05:40      Sun. 05:36    Sun. 05:01
# 33     Sun. 03:13           Sun. 06:21      Sun. 06:22    Sun. 05:42
# 34     Sun. 03:22           Sun. 06:31      Sun. 06:33    Sun. 05:52

# %%
Trails_objects[1].df_ppassage.columns.to_list()
# Out:
# ['id',
#  'Point_passage',
#  'Altitude_m',
#  'Cumul_Dist_km',
#  'Delta_Dist_km',
#  'Cumul_D+_m',
#  'Delta_D+_m',
#  'lon',
#  'lat',
#  'Heure_Passage',
#  'Temps_course',
#  'Classement',
#  'Vitesse_km/h',
#  'H_reel_h',
#  'Delta_reel_h',
#  'H_reel_h_init',
#  'Delta_reel_h_init',
#  'Trail',
#  'Pred_T_Rom',
#  'Pred_Cum_T_Rom',
#  'Heure_predite']

# %%
def plot_data(i1,i2,axeX,axeY1,axeY2):
    fig,ax = plt.subplots(figsize=(16,9))
    ax.plot(Trails_objects[i1].df_ppassage[axeX],Trails_objects[i1].df_ppassage[axeY1],c='blue')
    ax.plot(Trails_objects[i2].df_ppassage[axeX],Trails_objects[i2].df_ppassage[axeY2],c='red')
    ax.set_xlabel(axeX)
    ax.set_ylabel(f'{axeY1} {axeY2}')
    plt.legend([f'{Trails_objects[i1].nom_id} {axeY1}',f'{Trails_objects[i2].nom_id} {axeY2}'])
    plt.grid()

# %%
Trail_selection1 = widgets.Dropdown(
    options=[(Trails_objects[i].nom_id,i) for i in range(len(Trails_objects))],
    value=6,
    description='Trail1:',
)
Trail_selection2 = widgets.Dropdown(
    options=[(Trails_objects[i].nom_id,i) for i in range(len(Trails_objects))],
    value=6,
    description='Trail2:',
)
axeX = widgets.Dropdown(
    options=Trails_objects[1].df_ppassage.columns.to_list(),
    value='Cumul_Dist_km',
    description='Axe X:',
)
axeY1 = widgets.Dropdown(
    options=Trails_objects[1].df_ppassage.columns.to_list(),
    value='H_reel_h',
    description='Axe Y1:',
)
axeY2 = widgets.Dropdown(
    options=Trails_objects[1].df_ppassage.columns.to_list(),
    value='Pred_Cum_T_Rom',
    description='Axe Y2:',
)
ui1 = widgets.HBox([Trail_selection1,axeY1,axeX])
ui2 = widgets.HBox([Trail_selection2,axeY2])
res= widgets.interactive_output(plot_data,{'i1':Trail_selection1,'i2':Trail_selection2,'axeX':axeX,'axeY1':axeY1,'axeY2':axeY2})

display(ui1,ui2,res)
# Out:
# HBox(children=(Dropdown(description='Trail1:', index=6, options=(('20195REFUGES', 0), ('2019MCC', 1), ('2020GT…
# HBox(children=(Dropdown(description='Trail2:', index=6, options=(('20195REFUGES', 0), ('2019MCC', 1), ('2020GT…
# Output()
